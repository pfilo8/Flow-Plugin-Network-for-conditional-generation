# %%
# !pip install umap-learn

# %%
import matplotlib.pyplot as plt
import pandas as pd
import umap

# %%
data_path_train_z = "logs/DFCVAE/version_0/latent_space/z_train.csv"
data_path_train_y = "logs/DFCVAE/version_0/latent_space/y_train_gender.csv"
data_path_valid_z = "logs/DFCVAE/version_0/latent_space/z_valid.csv"
data_path_valid_y = "logs/DFCVAE/version_0/latent_space/y_valid_gender.csv"

# %%
df_train_z = pd.read_csv(data_path_train_z)
df_train_y = pd.read_csv(data_path_train_y)
df_valid_z = pd.read_csv(data_path_valid_z)
df_valid_y = pd.read_csv(data_path_valid_y)

# %%
reducer = umap.UMAP()

# %%
embedding = reducer.fit_transform(df_valid_z)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c = df_valid_y.values)
